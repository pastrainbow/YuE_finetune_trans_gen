# %%
import numpy as np
codes = np.load("/homes/al4624/Documents/YuE_finetune/YuE_finetune_trans_gen/finetune_output/stage1/guitar-upbeat-pop-inspiring_tp0@9_T1@0_rp2@0_maxtk1506_8048ae83-63dc-4786-a4bf-e72bb322f064_itrack.npy")[0:1, :]
print(codes)
dummy_codes = np.load("/homes/al4624/Documents/YuE_finetune/finetune_testing_dataset/mixture_codes_quant_1/078303.npy")
print(dummy_codes)

import numpy as np
import matplotlib.pyplot as plt

# Create a 1D NumPy array
# arr = dummy_codes[0][:1500]
# print(np.max(arr))
# # Plot the array
# plt.plot(arr)
# plt.title("dummy NumPy Array")
# plt.xlabel("Index")
# plt.ylabel("Value")
# plt.grid(True)
# plt.show()

# Create a 1D NumPy array
arr = codes[0]
print(np.max(arr))
# Plot the array
plt.plot(arr)
plt.title("dataset NumPy Array")
plt.xlabel("Index")
plt.ylabel("Value")
plt.grid(True)
plt.show()

# print(codes == dummy_codes)
# Out:
# [[ 84  84  84 ... 464 464 464]]
# [[ 427  591  184 ...  257   67 1001]]
# Matplotlib is building the font cache; this may take a moment.
# 1023
