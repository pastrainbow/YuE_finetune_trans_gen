# %%
import numpy as np
codes = np.load("/homes/al4624/Documents/silence.npy")[0:1, :]
print(codes)
dummy_codes = np.load("/homes/al4624/Documents/YuE_finetune/finetune_testing_dataset/mixture_codes_quant_1/078303.npy")
print(dummy_codes)

import numpy as np
import matplotlib.pyplot as plt

# Create a 1D NumPy array
# arr = dummy_codes[0][:1500]
# print(np.max(arr))
# # Plot the array
# plt.plot(arr)
# plt.title("dummy NumPy Array")
# plt.xlabel("Index")
# plt.ylabel("Value")
# plt.grid(True)
# plt.show()

# Create a 1D NumPy array
arr = codes[0]
print(np.max(arr))
# Plot the array
plt.plot(arr)
plt.title("dataset NumPy Array")
plt.xlabel("Index")
plt.ylabel("Value")
plt.grid(True)
plt.show()

# print(codes == dummy_codes)
# Out:
# [[464 464 464 ... 464 464 464]]
# [[ 427  591  184 ...  257   67 1001]]
# 464
