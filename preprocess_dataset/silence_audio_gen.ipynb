# %%
import soundfile as sf
import numpy as np
output_path = "/homes/al4624/Documents/silence.mp3"
sample_rate = 44100
length = 30 #in seconds
samples = np.zeros(length * sample_rate)
sf.write(output_path, samples, sample_rate)
