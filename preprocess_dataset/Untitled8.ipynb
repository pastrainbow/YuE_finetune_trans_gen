# %%
from pathlib import Path
import os
import shutil
track_dir = '/vol/bitbucket/al4624/finetune_dataset/fma_large/sep/noise_1.0'
track_paths = [str(file) for file in Path(track_dir).glob("*.mp3") if file.is_file()]
print(f"{len(track_paths)} tracks in total.")
# Out:
# 33876 tracks in total.

# %%
print(f"{len(track_paths)} tracks in total.")

output_dir = '/vol/bitbucket/al4624/finetune_dataset/fma_large/sep/eval'

eval_track_paths = track_paths[:1000]

for track_path in eval_track_paths:
    shutil.move(track_path, os.path.join(output_dir, Path(track_path).name))
# Out:
# 34876 tracks in total.
