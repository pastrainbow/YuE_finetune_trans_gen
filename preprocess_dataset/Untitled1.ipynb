# %%
import torchaudio
audio, sr = torchaudio.load("/homes/al4624/Documents/YuE_finetune/inference_audio_prompts/generated.wav")
print(audio)
# Out:
# tensor([[nan, nan, nan,  ..., nan, nan, nan],
#         [nan, nan, nan,  ..., nan, nan, nan]])
