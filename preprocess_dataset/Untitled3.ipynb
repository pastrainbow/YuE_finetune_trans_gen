# %%
import numpy as np
raw_codes = np.load("/homes/al4624/Documents/YuE_finetune/test_files/codes/dummy.npy")
# raw_codes = np.expand_dims(raw_codes, axis=0)
raw_codes = raw_codes[:, :5]
print(raw_codes)
print(raw_codes.shape)
print(raw_codes[0][0])
# Out:
# [[799  78 637 517 913]]
# (1, 5)
# 799
