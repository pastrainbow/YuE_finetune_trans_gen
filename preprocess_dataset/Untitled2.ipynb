# %%
import torch
from megatron.data import indexed_dataset

# Replace this with the actual path to your bin/idx files (without extension)
prefix = '/homes/al4624/Documents/YuE_finetune/YuE_finetune_trans_gen/finetune/example/mmap/trans_gen.msa.xcodec_16k_stage_1_token_level_interleave_long_prompt_msa_textfirst_inst_text_document'

# Load the dataset
dataset = indexed_dataset.make_dataset(prefix, 'infer', False)

# View number of documents (examples)
print(f"Number of documents: {len(dataset)}")

# View a specific document (as token IDs)
doc_index = 0
print(dataset[doc_index])

# If you want to decode it back to text
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained('gpt2')  # or whatever tokenizer you used

tokens = dataset[doc_index]
text = tokenizer.decode(tokens.tolist())
print(text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import torch
# ----> 2 from megatron.data import indexed_dataset
#       4 # Replace this with the actual path to your bin/idx files (without extension)
#       5 prefix = '/homes/al4624/Documents/YuE_finetune/YuE_finetune_trans_gen/finetune/example/mmap/trans_gen.msa.xcodec_16k_stage_1_token_level_interleave_long_prompt_msa_textfirst_inst_text_document'
#
# ModuleNotFoundError: No module named 'megatron.data'
