# %%
import numpy as np
codes = np.load("/homes/al4624/Documents/YuE_finetune/finetune_testing_dataset/mixture_codes/078303.npy")[0:1, :]
print(codes)
dummy_codes = np.load("/homes/al4624/Documents/YuE_finetune/YuE/finetune/example/npy/dummy.npy")
print(dummy_codes)

import numpy as np
import matplotlib.pyplot as plt

# Create a 1D NumPy array
arr = dummy_codes[0][:1500]
print(np.max(arr))
# Plot the array
plt.plot(arr)
plt.title("dummy NumPy Array")
plt.xlabel("Index")
plt.ylabel("Value")
plt.grid(True)
plt.show()

# Create a 1D NumPy array
arr = codes[0]
print(np.max(arr))
# Plot the array
plt.plot(arr)
plt.title("dataset NumPy Array")
plt.xlabel("Index")
plt.ylabel("Value")
plt.grid(True)
plt.show()
# Out:
# [[ 427  591  184 ...  257   67 1001]]
# [[ 799   78  637 ...  271  780 1000]]
# 1023
# 1023
